# %% [markdown]
# # ***EDA - Pima Indians Diabetes***

# %% [markdown]
# ### Yêu cầu:
# [1] Đọc paper, khảo sát bài toán liên quan
#
# [2] Phân tích khám phá dữ liệu
# + Xác định tính chất
# + Phân tích đơn biến
# + Phân tích đa biến
# + Xác định giá trị thiếu, và mẫu bất thường
# + Xác định ngoại lệ
